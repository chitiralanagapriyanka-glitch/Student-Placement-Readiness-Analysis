# %% [markdown]
# **STUDENT PLACEMENT READINESS ANALYSIS**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/Student_Placement_Readiness_Analysis_Records_Final.csv')

# %% [markdown]
# **EXPLORING DATASET**

# %%
#First 5 rows
df.head()
# Out:
#   1. Year of Study  2.  Current CGPA  \
# 0         2nd year              9.00
# 1         3rd year              8.60
# 2         3rd year              8.49
# 3         3rd year              8.23
# 4         3rd year              7.88
#
#   3. How many programming languages do you know?  \
# 0                                              2
# 1                                              1
# 2                                              3
# 3                                              3
# 4                                              1
#
#   4. How many hours do you practice coding per day?  \
# 0                                           3 hours
# 1                                 Less than 2 hours
# 2                                 Less than 2 hours
# 3                                    Not practicing
# 4                                    Not practicing
#
#    5. How many academic or personal projects have you completed?  \
# ...

# %%
#Last 5 rows
df.tail()
# Out:
#     1. Year of Study  2.  Current CGPA  \
# 115              NaN               NaN
# 116              NaN               NaN
# 117              NaN               NaN
# 118              NaN               NaN
# 119              NaN               NaN
#
#     3. How many programming languages do you know?  \
# 115                                            NaN
# 116                                            NaN
# 117                                            NaN
# 118                                            NaN
# 119                                            NaN
#
#     4. How many hours do you practice coding per day?  \
# 115                                               NaN
# 116                                               NaN
# 117                                               NaN
# 118                                               NaN
# 119                                               NaN
#
#      5. How many academic or personal projects have you completed?  \
# ...

# %%
df.columns=df.columns.str.strip()

# %%
#All Column names
df.columns
# Out:
# Index(['1. Year of Study', '2.  Current CGPA',
#        '3. How many programming languages do you know?',
#        '4. How many hours do you practice coding per day?',
#        '5. How many academic or personal projects have you completed?',
#        '6. Have you completed any internships?',
#        '7. How many certifications have you completed?',
#        '8. How would you rate your communication skills?',
#        '9. How often do you practice aptitude questions?',
#        '10. Have you participated in any hackathons or coding competitions?',
#        '11. Do you regularly practice coding on platforms like HackerRank,Leetcode or codechef?',
#        '12. Is your resume ready?',
#        '13. How confident are you in attending placement interviews?',
#        '14. Which skill do you think you need to improve the most?'],
#       dtype='object')

# %%
#No. of rows and columns
df.shape
# Out:
# (120, 14)

# %%
#Datatype of all columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 14 columns):
#  #   Column                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                   --------------  -----
#  0   1. Year of Study                                                                         103 non-null    object
#  1   2.  Current CGPA                                                                         98 non-null     float64
#  2   3. How many programming languages do you know?                                           103 non-null    object
#  3   4. How many hours do you practice coding per day?                                        103 non-null    object
#  4   5. How many academic or personal projects have you completed?                            103 non-null    float64
# ...

# %%
#Statistical summary for numeric columns
df.describe()
# Out:
#        2.  Current CGPA  \
# count         98.000000
# mean           8.561837
# std            0.532598
# min            7.000000
# 25%            8.407500
# 50%            8.660000
# 75%            8.970000
# max            9.200000
#
#        5. How many academic or personal projects have you completed?  \
# count                                         103.000000
# mean                                            1.601942
# std                                             0.953218
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             2.000000
# max                                             3.000000
#
#        8. How would you rate your communication skills?  \
# count                                        103.000000
# mean                                           4.533981
# ...

# %%
#Unique values in each column
df.nunique()
# Out:
# 1. Year of Study                                                                            3
# 2.  Current CGPA                                                                           24
# 3. How many programming languages do you know?                                              4
# 4. How many hours do you practice coding per day?                                           3
# 5. How many academic or personal projects have you completed?                               4
# 6. Have you completed any internships?                                                      2
# 7. How many certifications have you completed?                                              4
# 8. How would you rate your communication skills?                                            7
# 9. How often do you practice aptitude questions?                                            4
# 10. Have you participated in any hackathons or coding competitions?                         2
# ...

# %%
#Statistical summary for categorical columns
df.describe(include="object")
# Out:
#        1. Year of Study 3. How many programming languages do you know?  \
# count               103                                            103
# unique                3                                              4
# top            3rd year                                              3
# freq                 65                                             47
#
#        4. How many hours do you practice coding per day?  \
# count                                                103
# unique                                                 3
# top                                    Less than 2 hours
# freq                                                  53
#
#        6. Have you completed any internships?  \
# count                                     103
# unique                                      2
# top                                        No
# freq                                       52
#
#        7. How many certifications have you completed?  \
# ...

# %% [markdown]
# **DATA CLEANING**

# %%
#Checking Null values
df.isnull().sum()
# Out:
# 1. Year of Study                                                                           17
# 2.  Current CGPA                                                                           22
# 3. How many programming languages do you know?                                             17
# 4. How many hours do you practice coding per day?                                          17
# 5. How many academic or personal projects have you completed?                              17
# 6. Have you completed any internships?                                                     17
# 7. How many certifications have you completed?                                             21
# 8. How would you rate your communication skills?                                           17
# 9. How often do you practice aptitude questions?                                           17
# 10. Have you participated in any hackathons or coding competitions?                        17
# ...

# %%
# Fill missing values in numerical columns using mean
df['2.  Current CGPA']=df['2.  Current CGPA'].fillna(df['2.  Current CGPA'].mean())

# %%
df['4. How many hours do you practice coding per day?']=df['4. How many hours do you practice coding per day?'].fillna(df['4. How many hours do you practice coding per day?'].mode()[0])

# %%
df['7. How many certifications have you completed?'] = df['7. How many certifications have you completed?'].fillna(df['7. How many certifications have you completed?'].mode()[0])

# %%
df['13. How confident are you in attending placement interviews?'] = df['13. How confident are you in attending placement interviews?'].fillna(df['13. How confident are you in attending placement interviews?'].mean())

# %%
df.isnull().sum()
# Out:
# 1. Year of Study                                                                           17
# 2.  Current CGPA                                                                            0
# 3. How many programming languages do you know?                                             17
# 4. How many hours do you practice coding per day?                                           0
# 5. How many academic or personal projects have you completed?                              17
# 6. Have you completed any internships?                                                     17
# 7. How many certifications have you completed?                                              0
# 8. How would you rate your communication skills?                                           17
# 9. How often do you practice aptitude questions?                                           17
# 10. Have you participated in any hackathons or coding competitions?                        17
# ...

# %%
df['1. Year of Study']=df['1. Year of Study'].fillna(df['1. Year of Study'].mode()[0])

# %%
df['3. How many programming languages do you know?'] = df['3. How many programming languages do you know?'].fillna(df['3. How many programming languages do you know?'].mode()[0])

# %%
df['5. How many academic or personal projects have you completed?'] = df['5. How many academic or personal projects have you completed?'].fillna(df['5. How many academic or personal projects have you completed?'].mode()[0])

# %%
df['6. Have you completed any internships?'] = df['6. Have you completed any internships?'].fillna(df['6. Have you completed any internships?'].mode()[0])

# %%
df['8. How would you rate your communication skills?'] = df['8. How would you rate your communication skills?'].fillna(df['8. How would you rate your communication skills?'].mode()[0])

# %%
df['9. How often do you practice aptitude questions?'] = df['9. How often do you practice aptitude questions?'].fillna(df['9. How often do you practice aptitude questions?'].mode()[0])

# %%
df['10. Have you participated in any hackathons or coding competitions?'] = df['10. Have you participated in any hackathons or coding competitions?'].fillna(df['10. Have you participated in any hackathons or coding competitions?'].mode()[0])

# %%
df['11. Do you regularly practice coding on platforms like HackerRank,Leetcode or codechef?'] = df['11. Do you regularly practice coding on platforms like HackerRank,Leetcode or codechef?'].fillna(df['11. Do you regularly practice coding on platforms like HackerRank,Leetcode or codechef?'].mode()[0])

# %%
df['12. Is your resume ready?'] = df['12. Is your resume ready?'].fillna(df['12. Is your resume ready?'].mode()[0])

# %%
df['14. Which skill do you think you need to improve the most?'] = df['14. Which skill do you think you need to improve the most?'].fillna(df['14. Which skill do you think you need to improve the most?'].mode()[0])

# %%
df.isnull().sum()
# Out:
# 1. Year of Study                                                                           0
# 2.  Current CGPA                                                                           0
# 3. How many programming languages do you know?                                             0
# 4. How many hours do you practice coding per day?                                          0
# 5. How many academic or personal projects have you completed?                              0
# 6. Have you completed any internships?                                                     0
# 7. How many certifications have you completed?                                             0
# 8. How would you rate your communication skills?                                           0
# 9. How often do you practice aptitude questions?                                           0
# 10. Have you participated in any hackathons or coding competitions?                        0
# ...

# %%
#Checking duplicate values
df.duplicated().sum()
# Out:
# np.int64(34)

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **EPLORATORY DATA ANALYSIS(EDA)**

# %%
df.head()
# Out:
#   1. Year of Study  2.  Current CGPA  \
# 0         2nd year              9.00
# 1         3rd year              8.60
# 2         3rd year              8.49
# 3         3rd year              8.23
# 4         3rd year              7.88
#
#   3. How many programming languages do you know?  \
# 0                                              2
# 1                                              1
# 2                                              3
# 3                                              3
# 4                                              1
#
#   4. How many hours do you practice coding per day?  \
# 0                                           3 hours
# 1                                 Less than 2 hours
# 2                                 Less than 2 hours
# 3                                    Not practicing
# 4                                    Not practicing
#
#    5. How many academic or personal projects have you completed?  \
# ...

# %%
df.shape
# Out:
# (86, 14)

# %%
df.describe()
# Out:
#        2.  Current CGPA  \
# count         86.000000
# mean           8.545150
# std            0.551184
# min            7.000000
# 25%            8.430000
# 50%            8.600000
# 75%            8.970000
# max            9.200000
#
#        5. How many academic or personal projects have you completed?  \
# count                                          86.000000
# mean                                            1.639535
# std                                             0.906354
# min                                             0.000000
# 25%                                             1.250000
# 50%                                             2.000000
# 75%                                             2.000000
# max                                             3.000000
#
#        8. How would you rate your communication skills?  \
# count                                         86.000000
# mean                                           4.569767
# ...

# %%
df['1. Year of Study'].value_counts()
# Out:
# 1. Year of Study
# 3rd year    52
# 4th year    31
# 2nd year     3
# Name: count, dtype: int64

# %%
# Internship completed students

df['6. Have you completed any internships?'].value_counts()
# Out:
# 6. Have you completed any internships?
# No     43
# Yes    43
# Name: count, dtype: int64

# %%
# Certification analysis

df['7. How many certifications have you completed?'].value_counts()
# Out:
# 7. How many certifications have you completed?
# 1-2            38
# 0              23
# 3-5            13
# More than 5    12
# Name: count, dtype: int64

# %%
# Resume readiness analysis

df['12. Is your resume ready?'].value_counts()
# Out:
# 12. Is your resume ready?
# No     61
# Yes    25
# Name: count, dtype: int64

# %%
# Interview confidence analysis

df['13. How confident are you in attending placement interviews?'].value_counts()
# Out:
# 13. How confident are you in attending placement interviews?
# 3.000000    39
# 2.000000    21
# 4.000000    10
# 1.000000     9
# 5.000000     4
# 2.776699     3
# Name: count, dtype: int64

# %%
# Programming language knowledge analysis

df['3. How many programming languages do you know?'].value_counts()
# Out:
# 3. How many programming languages do you know?
# 3              40
# More than 3    20
# 1              14
# 2              12
# Name: count, dtype: int64

# %% [markdown]
# **VISUALIZATIONS**

# %%
import plotly.express as px

# %%
year_count = df['1. Year of Study'].value_counts()

fig = px.bar(
    x=year_count.index,
    y=year_count.values,
    title="Year of Study Distribution"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(
    df,
    x='2.  Current CGPA',
    title="Distribution of Student CGPA"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
language_count = df['3. How many programming languages do you know?'].value_counts()

fig = px.bar(
    x=language_count.index,
    y=language_count.values,
    title="Programming Languages Known by Students"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
coding_hours = df['4. How many hours do you practice coding per day?'].value_counts()

fig = px.pie(
    values=coding_hours.values,
    names=coding_hours.index,
    title="Daily Coding Practice Hours"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(
    df,
    y='5. How many academic or personal projects have you completed?',
    title="Projects Completed Distribution"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
internship = df['6. Have you completed any internships?'].value_counts()

fig = px.pie(
    values=internship.values,
    names=internship.index,
    title="Internship Completion Status"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
certification = df['7. How many certifications have you completed?'].value_counts()

fig = px.bar(
    x=certification.index,
    y=certification.values,
    title="Certification Completion Analysis"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(
    df,
    x='8. How would you rate your communication skills?',
    title="Communication Skills Rating Distribution"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
aptitude = df['9. How often do you practice aptitude questions?'].value_counts()

fig = px.pie(
    values=aptitude.values,
    names=aptitude.index,
    title="Aptitude Practice Frequency"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
hackathon = df['10. Have you participated in any hackathons or coding competitions?'].value_counts()

fig = px.pie(
    values=hackathon.values,
    names=hackathon.index,
    title="Hackathon Participation"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
platform = df['11. Do you regularly practice coding on platforms like HackerRank,Leetcode or codechef?'].value_counts()

fig = px.bar(
    x=platform.index,
    y=platform.values,
    title="Coding Platform Practice"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
resume = df['12. Is your resume ready?'].value_counts()

fig = px.pie(
    values=resume.values,
    names=resume.index,
    title="Resume Readiness Status"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(
    df,
    x='2.  Current CGPA',
    y='13. How confident are you in attending placement interviews?',
    title="CGPA vs Placement Confidence"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
skill = df['14. Which skill do you think you need to improve the most?'].value_counts()

fig = px.bar(
    x=skill.values,
    y=skill.index,
    orientation='h',
    title="Skills Students Need to Improve"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(
    df,
    x="2.  Current CGPA",
    y="13. How confident are you in attending placement interviews?",
    size="5. How many academic or personal projects have you completed?",
    color="6. Have you completed any internships?",
    hover_name="1. Year of Study",
    title="CGPA vs Placement Confidence Analysis"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(
    df,
    x="4. How many hours do you practice coding per day?",
    y="13. How confident are you in attending placement interviews?",
    color="6. Have you completed any internships?",
    title="Coding Practice vs Placement Confidence"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
year_data=df.groupby("1. Year of Study")["2.  Current CGPA"].mean()

fig=px.line(
    x=year_data.index,
    y=year_data.values,
    title="Average CGPA by Year of Study"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
intern=df.groupby("6. Have you completed any internships?")["13. How confident are you in attending placement interviews?"].mean()

fig=px.bar(
    x=intern.index,
    y=intern.values,
    title="Internship Impact on Placement Confidence"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.box(
    df,
    x="5. How many academic or personal projects have you completed?",
    y="2.  Current CGPA",
    title="Projects Completed vs CGPA"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.box(
    df,
    x="12. Is your resume ready?",
    y="2.  Current CGPA",
    title="Resume Readiness vs CGPA"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
skill=df["14. Which skill do you think you need to improve the most?"].value_counts()

fig=px.line(
    x=skill.index,
    y=skill.values,
    title="Skills Improvement Trend"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
